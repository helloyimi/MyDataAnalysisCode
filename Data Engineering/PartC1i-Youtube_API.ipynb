# %%
import numpy as np
import pandas as pd
from googleapiclient.discovery import build
import requests
import json
import urllib.request as urllib2
import time
import urllib
import datetime
import sys
import xlsxwriter
# sys.setdefaultencoding('utf-8')

# %%
#basic info for youtube api


api_key = 'AIzaSyByjUfsBezGY3_CvpVneAauaevXyN-WrWk'
channel_id = 'UCw8ZhLPdQ0u_Y-TLKd61hGA'
channel_api = 'https://developers.google.com/aapis-explorer/#p/youtube/v3/youtube.channels.list?part=snippet.contentDetails&publishAfter=2019-11-01T00:00:00Z&publishBefore=2020-12-31T00:00:00Z&id='+channel_id+'&key='+api_key
info_api='https://www.googleapis/youtube/v3/videos'

youtube = build('youtube','v3',developerKey = api_key)

# %%
# an empty list for stalling the information
video_ids = []
# get viedos in the channel
request = youtube.search().list(part='snippet,id',channelId = channel_id, maxResults=50,
                                publishedAfter='2017-01-01T00:00:00Z',publishedBefore='2020-12-31T00:00:00Z')
response = request.execute()

for i in response['items']:
    try:
        video_ids.append(i['id']['videoId'])#get the videoID
    except:
        pass

# %%
print (len(video_ids))
dict = {'VideoID':[], 'title':[], 'publishedAt':[], 'viewCount':[], 'likeCount':[], 'dislikeCount':[]}
query = ''
for i in video_ids:
#     query = video_ids[i]
    request = youtube.videos().list(id = i, part='snippet,statistics',maxResults=50).execute()
    for j in request['items']:
        dict['VideoID'].append(i)
        dict['likeCount'].append(j['statistics']['likeCount'])
        dict['dislikeCount'].append(j['statistics']['dislikeCount'])
        dict['viewCount'].append(j['statistics']['dislikeCount'])
        dict['publishedAt'].append(j['snippet']['publishedAt'])
        dict['title'].append(j['snippet']['title'])
# Out:
# 50

# %%
df = pd.DataFrame(dict)
df.index = np.arange(1,len(df)+1)
df
# Out:
#         VideoID                                              title  \
# 1   X6Brmaf27Tg  MAMAMOO - Dingga / Lia Kim X JJ Original Chore...
# 2   kn7VB3CIxYk  Cardi B - WAP ft. Megan Thee Stallion / Isabel...
# 3   Uvy_o058T40                             1MILLION X K/DA - MORE
# 4   zbWsb36U0uo  Wolves - Selena Gomez, Marshmello / Jun Liu Ch...
# 5   3vkcibPGGMk     Wrongest Way - Sonny / Junsun Yoo Choreography
# 6   Tt4QpBwvJww       Vedo - P*$$Y FAIRY / Austin Pak Choreography
# 7   F1RfQP1cxbg  Give Me More - VAV / Mina Myoung Choreography ...
# 8   6fdXsoVNJis  EVERGLOW - LA DI DA / Haejun X Tina Boo X Lia ...
# 9   TzWa3Q8Jd6E                   We Don’t Need A Stage - 1MILLION
# 10  W7_TmTucL78  Abusadamente (Remix) - MC Gustta e MC DG / May...
# 11  16LIH3jG5NA  Tones and I - Ur So F**kInG cOoL / Yeji Kim Ch...
# 12  7Qi3b41xrRs  Workin - Josh Killacky / Dokteuk Crew Choreogr...
# 13  idTrlabUE84  Do What It Do - Jamie Foxx / Isabelle Choreogr...
# ...

# %%
df.to_csv(r'./YoutubeApi.csv')
